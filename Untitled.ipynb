# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("housing_price_dataset.csv")

# %%
data
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SquareFeet    50000 non-null  int64
#  1   Bedrooms      50000 non-null  int64
#  2   Bathrooms     50000 non-null  int64
#  3   Neighborhood  50000 non-null  object
#  4   YearBuilt     50000 non-null  int64
#  5   Price         50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['Price'], axis=1)
y = data['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)
test_data = X_test.join(y_test)
train_data = train_data.join(pd.get_dummies(train_data.Neighborhood, dtype=int)).drop(["Neighborhood"], axis=1)
test_data = test_data.join(pd.get_dummies(test_data.Neighborhood, dtype=int)).drop(["Neighborhood"], axis=1)

train_data
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt          Price  Rural  \
# 30305        2854         5          3       2014  345745.107839      0
# 12697        2926         2          3       1995  301870.119847      0
# 2804         2969         4          2       2010  334202.169999      1
# 6378         2652         2          2       2017  356229.432556      1
# 2602         1311         2          2       1964   88652.936536      0
# ...           ...       ...        ...        ...            ...    ...
# 30959        1679         4          2       1983  184603.688722      0
# 25249        2369         3          1       1967  157502.920441      0
# 45481        2592         5          2       1987  282751.396393      0
# 9192         2807         4          1       2007  290925.478987      1
# 5732         1009         5          3       1968  151533.061109      0
#
#        Suburb  Urban
# 30305       1      0
# 12697       1      0
# 2804        0      0
# 6378        0      0
# 2602        1      0
# ...       ...    ...
# 30959       0      1
# 25249       1      0
# 45481       1      0
# 9192        0      0
# 5732        0      1
#
# [40000 rows x 8 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'SquareFeet'}>,
#         <Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Bathrooms'}>],
#        [<Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Rural'}>],
#        [<Axes: title={'center': 'Suburb'}>,
#         <Axes: title={'center': 'Urban'}>, <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression


X_train = train_data.drop(['Price'], axis=1)

y_train = train_data['Price']

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test = test_data.drop(['Price'], axis=1)

y_test = test_data['Price']


model.score(X_test, y_test)
# Out:
# 0.5723795977898383

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
forest.score(X_test, y_test)
# Out:
# 0.5234001137626427

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [50, 100, 200],
    "max_features": [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [50, 100, 200]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test, y_test)
# Out:
# 0.525845189599538

# %%
import pickle

pickle.dump("")
